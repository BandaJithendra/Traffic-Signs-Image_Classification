# %%
import numpy as np # linear algebra
import matplotlib.pyplot as plt
import os
from PIL import Image
from numpy import asarray
from sklearn.model_selection import train_test_split

# %%
from keras.models import Sequential, load_model
from keras import la,kllyers
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dense
from keras.preprocessing import image
# Out:
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

# %%
data_path = "D:/Gundu/DeepLearning_Projects/Traffic/data/"

# %%
classes = os.listdir(data_path)

# %%
classes
# Out:
# ['0 (1).jpg',
#  '0 (10).jpg',
#  '0 (100).jpg',
#  '0 (101).jpg',
#  '0 (102).jpg',
#  '0 (103).jpg',
#  '0 (104).jpg',
#  '0 (105).jpg',
#  '0 (106).jpg',
#  '0 (107).jpg',
#  '0 (108).jpg',
#  '0 (109).jpg',
#  '0 (11).jpg',
#  '0 (110).jpg',
#  '0 (111).jpg',
#  '0 (112).jpg',
#  '0 (113).jpg',
#  '0 (114).jpg',
#  '0 (115).jpg',
#  '0 (116).jpg',
#  '0 (117).jpg',
#  '0 (118).jpg',
#  '0 (119).jpg',
#  '0 (12).jpg',
#  '0 (120).jpg',
#  '0 (121).jpg',
#  '0 (122).jpg',
#  '0 (123).jpg',
#  '0 (124).jpg',
#  '0 (125).jpg',
#  '0 (126).jpg',
#  '0 (127).jpg',
#  '0 (128).jpg',
#  '0 (129).jpg',
#  '0 (13).jpg',
#  '0 (130).jpg',
#  '0 (131).jpg',
#  '0 (132).jpg',
#  '0 (133).jpg',
#  '0 (134).jpg',
#  '0 (135).jpg',
#  '0 (136).jpg',
#  '0 (137).jpg',
#  '0 (138).jpg',
#  '0 (139).jpg',
#  '0 (14).jpg',
#  '0 (140).jpg',
#  '0 (141).jpg',
#  '0 (142).jpg',
#  '0 (143).jpg',
#  '0 (144).jpg',
#  '0 (145).jpg',
#  '0 (146).jpg',
#  '0 (147).jpg',
#  '0 (148).jpg',
# ...

# %%
len(classes)
# Out:
# 73139

# %%
print(classes[69600])
# Out:
# 8 (324).jpg

# %%
print(classes[5350])
# Out:
# 1 (980).jpg

# %%
if classes[6000][:2][1]==' ':
    print(classes[6000][0])
    print("YES")
else:
    print("None")
    print(classes[5000][:2])
# Out:
# None
# 1

# %%
a = int(classes[50000][:2])
print(a)
type(a)
# Out:
# 36
# int

# %%
train_images = np.array([])
train_labels = np.array([])

# %%
list_ = []
list_2 = []
# train_images = asarray(train_images)
# idx=0
for i in classes:
    if i[1]==" ":
        list_2.append(int(i[0]))
    else:
        list_2 .append(int(i[:2]))
    img = Image.open(data_path + i)
    # img = img.resize((64,64))
    data = asarray(img)
    # print(data.shape)
    list_.append(data)

# %%
list_[0]
# Out:
# array([[[234, 251, 255],
#         [188, 208, 232],
#         [187, 210, 228],
#         ...,
#         [ 39,  51,  67],
#         [ 37,  43,  69],
#         [ 37,  42,  72]],
#
#        [[234, 251, 255],
#         [188, 208, 232],
#         [184, 210, 225],
#         ...,
#         [ 51,  63,  77],
#         [ 55,  63,  84],
#         [ 61,  68,  94]],
#
#        [[234, 254, 255],
#         [187, 209, 230],
#         [182, 210, 224],
#         ...,
#         [ 65,  80,  87],
#         [ 67,  81,  94],
#         [ 73,  84, 102]],
#
#        ...,
#
#        [[231, 253, 255],
#         [177, 200, 218],
#         [167, 193, 208],
#         ...,
#         [147, 151, 150],
#         [150, 152, 151],
#         [153, 153, 153]],
#
#        [[231, 250, 255],
#         [175, 196, 225],
#         [165, 189, 213],
#         ...,
#         [163, 167, 168],
#         [165, 166, 171],
#         [177, 176, 182]],
#
#        [[231, 249, 255],
#         [174, 194, 227],
#         [165, 186, 215],
# ...

# %%
len(list_)
# Out:
# 73139

# %%
list_[0].shape
# Out:
# (32, 32, 3)

# %%
images = np.array(list_)

# %%
type(images)
# Out:
# numpy.ndarray

# %%
labels = np.array(list_2)

# %%
images.shape
# Out:
# (73139, 32, 32, 3)

# %%
labels.shape
# Out:
# (73139,)

# %%
labels
# Out:
# array([0, 0, 0, ..., 9, 9, 9])

# %%
for i in labels:
    if i>10:
        print(i)
# Out:
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# ...

# %%
s = set(labels)
len(s)
# Out:
# 43

# %% [markdown]
# train_images,train_labels,test_images,test_labels = train_test_split(images,labels,split_size=0.2,random_state=41)

# %%
train_images,test_images,train_labels,test_labels = train_test_split(images,labels,test_size=0.2,random_state=41)

# %%
len(train_images)
# Out:
# 58511

# %%
len(train_labels)
# Out:
# 58511

# %%
len(test_images)
# Out:
# 14628

# %%
len(test_labels)
# Out:
# 14628

# %%
train_labels
# Out:
# array([38,  5, 12, ...,  5,  1, 25])

# %%
pic = Image.fromarray(train_images[-1])

# %%
pic
# Out:
# <PIL.Image.Image image mode=RGB size=32x32>

# %%
train_images = train_images/255.0

# %%
test_images = test_images/255.0

# %%
train_images
# Out:
# array([[[[0.55686275, 0.50196078, 0.50196078],
#          [0.56078431, 0.50588235, 0.50588235],
#          [0.55294118, 0.50588235, 0.50588235],
#          ...,
#          [0.20392157, 0.17647059, 0.10588235],
#          [0.2       , 0.14509804, 0.19607843],
#          [0.24705882, 0.18431373, 0.29019608]],
#
#         [[0.57647059, 0.52156863, 0.52156863],
#          [0.57254902, 0.51764706, 0.51764706],
#          [0.55294118, 0.50588235, 0.50588235],
#          ...,
#          [0.22745098, 0.2       , 0.1372549 ],
#          [0.22352941, 0.16862745, 0.21960784],
#          [0.24705882, 0.18431373, 0.29019608]],
#
#         [[0.41568627, 0.36078431, 0.35686275],
#          [0.4       , 0.34509804, 0.34509804],
#          [0.37647059, 0.32941176, 0.32941176],
#          ...,
#          [0.23137255, 0.20392157, 0.16470588],
#          [0.23137255, 0.18431373, 0.23921569],
#          [0.22352941, 0.16862745, 0.26666667]],
#
#         ...,
#
# ...

# %%
categories = ["Speed limit (20km/h)","Speed limit (30km/h)","Speed limit (50km/h)","Speed limit (60km/h)",
              "Speed limit (70km/h)","Speed limit (80km/h)","End of speed limit (80km/h)","Speed limit (100km/h)",
              "Speed limit (120km/h)","No passing","No passing for vechiles over 3.5 metric tons",
              "Right-of-way at the next intersection","Priority road","Yield","Stop","No vechiles",
              "Vechiles over 3.5 metric tons prohibited","No Entry","General caution","Dangerous curve to the left",
              "Dangerous curve to the right","Double curve","Bumpy road","Slippery road","Road narrows on the right",
              "Road work","Traffic signals","Pedestrians","Children crossing","Bicycles crossing","Beware of ice/snow",
              "Wild animals crossing","End of all speed and passing limits","Turn right ahead","Turn left ahead",
              "Ahead only","Go straight or right","Go straight or left","Keep right","Keep left","Roundabout mandatory",
              "End of no passing","End of no passing by vechiles over 3.5 metric tons"]

# %%
len(categories)
# Out:
# 43

# %%
def plot_sample(x,y,index):
    plt.figure(figsize=(15,2))
    plt.imshow(x[index])
    plt.xlabel(categories[y[index]])

# %%
plot_sample(train_images,train_labels,3)

# %%
plot_sample(train_images,train_labels,60)

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(3,3))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
# model.add(Conv2D(64,(5,5),activation='relu'))
# model.add(MaxPooling2D(2,2))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_6 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 2, 2, 64)          36928
#
#  max_pooling2d_8 (MaxPoolin  (None, 1, 1, 64)          0
#  g2D)
#
# ...
# Total params: 56320 (220.00 KB)
# Trainable params: 56320 (220.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(50,activation='relu'))
# model.add(Dropout(0.1))
model.add(Dense(43,activation='relu'))
# model.add(layers.Dense(2,activation='softmax'))
# model.add(Dense(2,activation='softmax'))
model.add(Dense(43,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_6 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_6 (MaxPoolin  (None, 15, 15, 32)        0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 4, 64)          0
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 2, 2, 64)          36928
#
#  max_pooling2d_8 (MaxPoolin  (None, 1, 1, 64)          0
#  g2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 50)                3250
#
#  dense_1 (Dense)             (None, 43)                2193
#
#  dense_2 (Dense)             (None, 43)                1892
#
# ...
# Total params: 63655 (248.65 KB)
# Trainable params: 63655 (248.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
history = model.fit(train_images,train_labels,epochs=10,validation_data=(test_images,test_labels))
# Out:
# Epoch 1/10
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 1829/1829 [==============================] - 36s 17ms/step - loss: 1.5220 - accuracy: 0.5629 - val_loss: 0.4982 - val_accuracy: 0.8452
# Epoch 2/10
# 1829/1829 [==============================] - 27s 15ms/step - loss: 0.3254 - accuracy: 0.9053 - val_loss: 0.1991 - val_accuracy: 0.9438
# Epoch 3/10
# 1829/1829 [==============================] - 30s 16ms/step - loss: 0.1673 - accuracy: 0.9511 - val_loss: 0.1266 - val_accuracy: 0.9658
# Epoch 4/10
# ...

# %%
plt.plot(history.history['accuracy'],label ='accuracy')
plt.plot(history.history['val_accuracy'],label ='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5,1])
plt.legend(loc='upper right')

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
test_acc = model.evaluate(test_images,test_labels,verbose=2)
# Out:
# 458/458 - 2s - loss: 0.0418 - accuracy: 0.9887 - 2s/epoch - 4ms/step

# %%
print(test_acc)
# Out:
# [0.04182681068778038, 0.9886518716812134]

# %%
pred_values = model.predict(test_images)
# Out:
# 458/458 [==============================] - 2s 5ms/step

# %%
pred_values[6]
# Out:
# array([1.6790528e-24, 2.9179144e-16, 2.4127896e-14, 7.5416597e-09,
#        1.0250660e-12, 4.2445956e-11, 5.3703230e-25, 1.7840974e-19,
#        1.4979504e-13, 3.4602168e-11, 3.3404078e-15, 6.1397209e-34,
#        1.9879758e-11, 1.7854884e-17, 4.5901301e-27, 1.0000000e+00,
#        8.3602177e-25, 2.1657823e-30, 1.6373352e-20, 3.3614685e-26,
#        4.0086418e-19, 2.8195514e-33, 3.1633558e-13, 2.4059003e-26,
#        1.2632593e-32, 1.3106861e-21, 2.3527863e-19, 0.0000000e+00,
#        4.7908574e-19, 1.7072324e-16, 1.5508171e-30, 1.7668950e-26,
#        1.1170840e-15, 3.8647471e-19, 1.6856559e-17, 1.3998030e-13,
#        2.7039425e-19, 2.6924006e-37, 4.1574132e-14, 6.8516474e-28,
#        1.2489162e-20, 2.0090568e-17, 4.3495383e-23], dtype=float32)

# %%
pred_classes = [np.argmax(e) for e in pred_values]

# %%
test_labels[:5]
# Out:
# array([ 9, 12, 10, 19, 41])

# %%
pred_classes[:5]
# Out:
# [9, 12, 10, 19, 41]

# %%
len(pred_classes)
# Out:
# 14628

# %%
test_labels[14620:]
# Out:
# array([31, 38, 32,  5, 33, 10, 22, 38])

# %%
pred_classes[14620:]
# Out:
# [31, 38, 32, 5, 33, 10, 22, 38]

# %%
test_labels[1200:1210]
# Out:
# array([17,  9, 25,  4,  7,  1, 13,  8, 38, 25])

# %%
pred_classes[1200:1210]
# Out:
# [17, 9, 25, 4, 7, 1, 13, 8, 38, 25]

# %%
import tensorflow as tf

# %%
keras_file="Model"
tf.keras.models.save_model(model,keras_file)
# Out:
# INFO:tensorflow:Assets written to: Model\assets
# INFO:tensorflow:Assets written to: Model\assets

# %%
plot_sample(test_images,test_labels,0)

# %%
categories[pred_classes[0]]
# Out:
# 'No passing'

# %%
plot_sample(test_images,test_labels,7)

# %%
categories[pred_classes[7]]
# Out:
# 'Speed limit (70km/h)'

# %%
plot_sample(test_images,test_labels,440)

# %%
categories[pred_classes[440]]
# Out:
# 'Keep right'

# %%
img = Image.open("D:/Gundu/DeepLearning_Projects/Traffic/Turn right ahead.png")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
img = img.resize((32,32))
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)
preds=model.predict(x)
pred = np.argmax(preds, axis=-1)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
print(pred[0])
categories[pred[0]]
# Out:
# 33
# 'Turn right ahead'
